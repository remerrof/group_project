# %% [markdown]
# Title

# %%
Title:

# %% [markdown]
# Introduction:
#
# Pulsars can generate Earth-detectable radio emissions by rotating at high speeds. Each pulsar rotates slightly differently, and because of the effects of radio frequency interference (RFI) and noise on pulsars , the right signal can be difficult to detect. Therefore, researchers need to find the legitimate signals by analyzing the dataset. The shared dataset contains 16,259 false examples caused by RFI and noise, and 1,639 real pulsar examples that human annotators have checked.
#
# We want to build a binary classifier to predict whether the candidates are "pulsar" or "non-pulsar". The data used is from the HTRU_2 dataset.

# %% [markdown]
# Preliminary Data Analysis:

# %%
import pandas as pd
import altair as alt
import numpy as np

# %%
pulsar_data = pd.read_csv("/home/jovyan/group_project/HTRU_2.csv", header = None, names = [
    "Mean",
    "Sd",
    "Excess_kurtosis",
    "Skewness",
    "Mean_DM-SNR_curve",
    "Sd_DM-SNR_curve",
    "Excess_kurtosis_DM-SNR_curve",
    "Skewness_DM-SNR_curve",
    "Class"
],)

pulsar_data["Class"]=pulsar_data["Class"].replace({
    0: "Non_pulsar",
    1: "Pulsar"
})

pulsar_data
# Out:
#              Mean         Sd  Excess_kurtosis  Skewness  Mean_DM-SNR_curve  \
# 0      140.562500  55.683782        -0.234571 -0.699648           3.199833
# 1      102.507812  58.882430         0.465318 -0.515088           1.677258
# 2      103.015625  39.341649         0.323328  1.051164           3.121237
# 3      136.750000  57.178449        -0.068415 -0.636238           3.642977
# 4       88.726562  40.672225         0.600866  1.123492           1.178930
# ...           ...        ...              ...       ...                ...
# 17893  136.429688  59.847421        -0.187846 -0.738123           1.296823
# 17894  122.554688  49.485605         0.127978  0.323061          16.409699
# 17895  119.335938  59.935939         0.159363 -0.743025          21.430602
# 17896  114.507812  53.902400         0.201161 -0.024789           1.946488
# 17897   57.062500  85.797340         1.406391  0.089520         188.306020
#
# ...

# %% [markdown]
# Methods
#
# We will use train-test split and the K-Nearest Neighbors Classification to find the best k and test how well our classifier works on a random test sample. To do this, we would calculate the precision, accuracy and recall rate of the first classifier built from the training set by predicting the class of the test set, and then comparing it with the actual result. Then based on that result we should then be able to find the best K-nearest neighbor through choosing the best level of cross-validation and selecting the smaller K-nearest neighbor number with the higher accuracy rate. Afterwards, we would test predicting the classes of a random sample by comparing the generated result with the actual class of it twice, once with the original classifier, and once with the improved classifier.

# %% [markdown]
# What do we expect to find?
#
# We are expected to find the goodness of our classifier, improve it with the best K-nearest neighbor and then test it on a randomly generated sample and then test the accuracy and efficiency of the new classifier. When testing the first classifier we expect the results to not be super accurate, and the k value to be high. However, we expect to see an improvement after we make adjustments, letting the K-nearest neighbor value to be lower.

# %% [markdown]
# What impact could such findings have?
#
# After testing the accuracy of our original Classifier and finding the best number for K-nearest neighbor, our classifier is improved, leading to a higher accuracy and precision with a lower recall rate. This resolves a lot of inefficiencies in the real world and allows astronomers to make better predictions on stars within a limited budget and time.
